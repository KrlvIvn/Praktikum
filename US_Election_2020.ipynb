# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r'C:\Users\Пользователь.DESKTOP-D8OKDU5\Projects\Notebooks\DataSet\archive_usa_2020\president_county.csv')

# %%
df['state']
# Out:
# 0                   Delaware
# 1                   Delaware
# 2                   Delaware
# 3       District of Columbia
# 4       District of Columbia
#                 ...
# 4628                 Arizona
# 4629                 Arizona
# 4630                 Arizona
# 4631                 Arizona
# 4632                 Arizona
# Name: state, Length: 4633, dtype: object

# %%
df['state'].unique()
# Out:
# array(['Delaware', 'District of Columbia', 'Florida', 'Georgia', 'Hawaii',
#        'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky',
#        'Louisiana', 'Maine', 'Maryland', 'Massachusetts', 'Michigan',
#        'Minnesota', 'Mississippi', 'Missouri', 'Montana', 'Nebraska',
#        'Nevada', 'New Hampshire', 'New Jersey', 'New Mexico', 'New York',
#        'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma', 'Oregon',
#        'Pennsylvania', 'Rhode Island', 'South Carolina', 'South Dakota',
#        'Tennessee', 'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington',
#        'West Virginia', 'Wisconsin', 'Wyoming', 'Alabama', 'Arkansas',
#        'California', 'Colorado', 'Connecticut', 'Alaska', 'Arizona'],
#       dtype=object)

# %%
df = df.drop(labels='county', axis=1)

# %%
df
# Out:
#                      state  current_votes  total_votes  percent
# 0                 Delaware          86958        88000       95
# 1                 Delaware         286133       293878       95
# 2                 Delaware         129293       125000       95
# 3     District of Columbia          31260        45392       69
# 4     District of Columbia          27259        37140       73
# ...                    ...            ...          ...      ...
# 4628               Arizona          14993        14995       95
# 4629               Arizona           3685         3690       95
# 4630               Arizona           6671         7500       89
# 4631               Arizona        2038832      2072000       95
# 4632               Arizona         103692       106000       95
#
# [4633 rows x 4 columns]

# %%
votes = df.groupby(['state'])['current_votes','total_votes'].sum()
# Out:
# <ipython-input-190-a69f950776ca>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   votes = df.groupby(['state'])['current_votes','total_votes'].sum()

# %%
percent = df.groupby(['state'])['percent'].mean()

# %%
votes.shape
# Out:
# (51, 2)

# %%
percent.shape
# Out:
# (51,)

# %%
votes['percent']=percent

# %%
votes
# Out:
#                       current_votes  total_votes    percent
# state
# Alabama                     2309900      2253098  97.164179
# Alaska                       131885       366006  35.300000
# Arizona                     3322535      3403744  94.200000
# Arkansas                    1216818      1250053  93.226667
# California                 14414296     15813337  85.500000
# Colorado                    3173127      3222600  95.265625
# Connecticut                 1786557      1839726  93.662722
# Delaware                     502384       506878  95.000000
# District of Columbia         279152       348619  79.750000
# Florida                    11075706     11321757  96.746269
# Georgia                     4983735      4963669  98.955975
# Hawaii                       573854       551047  95.000000
# Idaho                        867971       851364  95.500000
# Illinois                    6467031      7258430  93.475728
# Indiana                     3031629      3016145  96.793478
# ...
